# %%
import numpy as np
import pandas as pd
import plotly.express as px

from os.path import getsize

from chessf.engine import Stockfish

# import statsmodels.api as sm

# %% [markdown]
# **Parsing functions**

# %%
PGN_FILE = "pgn/lichess_db_chess960_rated_2025-10.pgn"
print(f"PGN file size (bytes): {getsize(PGN_FILE):,}")

f = open(PGN_FILE, mode="r")
# Out:
# PGN file size (bytes): 898,587,353

# %%
for _ in range(500):
    line = f.readline()
    print(line, end="")
# Out:
# [Event "Rated Chess960 game"]
# [Site "https://lichess.org/JNTEWgur"]
# [Date "2025.10.01"]
# [Round "-"]
# [White "Blindcatkelevra"]
# [Black "paparoach"]
# [Result "1-0"]
# [UTCDate "2025.10.01"]
# [UTCTime "00:37:15"]
# [WhiteElo "2053"]
# [BlackElo "1982"]
# [WhiteRatingDiff "+8"]
# [BlackRatingDiff "-4"]
# [TimeControl "30+1"]
# [Termination "Normal"]
# [FEN "bbrqnnkr/pppppppp/8/8/8/8/PPPPPPPP/BBRQNNKR w KQkq - 0 1"]
# [SetUp "1"]
# [Variant "Chess960"]
#
# 1. d4 { [%clk 0:00:30] } 1... b6 { [%clk 0:00:30] } 2. c4 { [%clk 0:00:30] } 2... d5 { [%clk 0:00:31] } 3. b3 { [%clk 0:00:30] } 3... dxc4 { [%clk 0:00:31] } 4. bxc4 { [%clk 0:00:31] } 4... Ng6 { [%clk 0:00:30] } 5. e4 { [%clk 0:00:31] } 5... Nf6 { [%clk 0:00:29] } 6. e5 { [%clk 0:00:29] } 6... Nd7 { [%clk 0:00:30] } 7. Nd3 { [%clk 0:00:27] } 7... e6 { [%clk 0:00:29] } 8. Ng3 { [%clk 0:00:27] } 8... O-O { [%clk 0:00:30] } 9. O-O { [%clk 0:00:27] } 9... c5 { [%clk 0:00:30] } 10. Nh5 { [%clk 0:00:13] } 10... cxd4 { [%clk 0:00:28] } 11. f4 { [%clk 0:00:13] } 11... f5 { [%clk 0:00:22] } 12. exf6 { [%clk 0:00:13] } 12... Nxf6 { [%clk 0:00:22] } 13. Ne5 { [%clk 0:00:07] } 13... Bxe5 { [%clk 0:00:17] } 14. fxe5 { [%clk 0:00:06] } 14... Nxh5 { [%clk 0:00:17] } 15. Qxh5 { [%clk 0:00:05] } 15... Qh4 { [%clk 0:00:11] } 16. Bxg6 { [%clk 0:00:04] } 16... Qxh5 { [%clk 0:00:05] } 17. Bxh5 { [%clk 0:00:05] } 17... Rxf1+ { [%clk 0:00:05] } 18. Rxf1 { [%clk 0:00:05] } 18... Rxc4 { [%clk 0:00:05] } 19. Be2 { [%clk 0:00:05] } 19... Rc2 { [%clk 0:00:05] } 20. Bf3 { [%clk 0:00:04] } 20... d3 { [%clk 0:00:05] } 21. Bxa8 { [%clk 0:00:03] } 21... d2 { [%clk 0:00:05] } 22. Bf3 { [%clk 0:00:04] } 22... Rc1 { [%clk 0:00:05] } 23. Kf2 { [%clk 0:00:03] } 23... Rxf1+ { [%clk 0:00:05] } 24. Kxf1 { [%clk 0:00:04] } 24... d1=Q+ { [%clk 0:00:06] } 25. Bxd1 { [%clk 0:00:04] } 1-0
#
# [Event "Rated Chess960 game"]
# [Site "https://lichess.org/qsHl1pI5"]
# [Date "2025.10.01"]
# [Round "-"]
# [White "F1scherRandomChess"]
# [Black "Panchajanya09"]
# [Result "0-1"]
# [UTCDate "2025.10.01"]
# [UTCTime "00:37:21"]
# [WhiteElo "1911"]
# [BlackElo "1992"]
# [WhiteRatingDiff "-4"]
# [BlackRatingDiff "+57"]
# [TimeControl "30+0"]
# [Termination "Normal"]
# [FEN "rbqkbnrn/pppppppp/8/8/8/8/PPPPPPPP/RBQKBNRN w KQkq - 0 1"]
# [SetUp "1"]
# [Variant "Chess960"]
#
# 1. c3 { [%clk 0:00:30] } 1... Nhg6 { [%clk 0:00:30] } 2. Nhg3 { [%clk 0:00:30] } 2... Ne6 { [%clk 0:00:30] } 3. e4 { [%clk 0:00:30] } 3... c5 { [%clk 0:00:29] } 4. d4 { [%clk 0:00:29] } 4... cxd4 { [%clk 0:00:28] } 5. f4 { [%clk 0:00:28] } 5... Ngxf4 { [%clk 0:00:27] } 6. Nd2 { [%clk 0:00:27] } 6... d3 { [%clk 0:00:26] } 7. Bf2 { [%clk 0:00:26] } 7... Ne2 { [%clk 0:00:25] } 8. Nxe2 { [%clk 0:00:25] } 8... dxe2+ { [%clk 0:00:25] } 9. Kxe2 { [%clk 0:00:24] } 9... Nf4+ { [%clk 0:00:25] } 10. Kf3 { [%clk 0:00:24] } 10... g5 { [%clk 0:00:23] } 11. g3 { [%clk 0:00:23] } 11... g4+ { [%clk 0:00:23] } 12. Ke3 { [%clk 0:00:21] } 12... Qc5# { [%clk 0:00:22] } 0-1
#
# [Event "Rated Chess960 game"]
# [Site "https://lichess.org/Vnasf6Pi"]
# [Date "2025.10.01"]
# [Round "-"]
# [White "Porubator"]
# [Black "Karavaha"]
# [Result "1-0"]
# [UTCDate "2025.10.01"]
# [UTCTime "00:38:07"]
# [WhiteElo "1895"]
# [BlackElo "1882"]
# [WhiteRatingDiff "+5"]
# [BlackRatingDiff "-6"]
# [TimeControl "180+2"]
# [Termination "Time forfeit"]
# [FEN "rnkqrbbn/pppppppp/8/8/8/8/PPPPPPPP/RNKQRBBN w KQkq - 0 1"]
# [SetUp "1"]
# [Variant "Chess960"]
#
# 1. e4 { [%clk 0:03:00] } 1... f6 { [%clk 0:03:00] } 2. d4 { [%clk 0:03:00] } 2... e5 { [%clk 0:03:01] } 3. d5 { [%clk 0:03:00] } 3... Nf7 { [%clk 0:02:59] } 4. c4 { [%clk 0:02:57] } 4... Bc5 { [%clk 0:02:59] } 5. Nc3 { [%clk 0:02:53] } 5... a6 { [%clk 0:02:58] } 6. Qd2 { [%clk 0:02:53] } 6... d6 { [%clk 0:02:57] } 7. Ng3 { [%clk 0:02:34] } 7... Nd7 { [%clk 0:02:50] } 8. Be2 { [%clk 0:02:28] } 8... g6 { [%clk 0:02:43] } 9. Bg4 { [%clk 0:02:23] } 9... h5 { [%clk 0:02:41] } 10. Bh3 { [%clk 0:02:21] } 10... Ng5 { [%clk 0:02:41] } 11. f4 { [%clk 0:02:08] } 11... Nxh3 { [%clk 0:02:40] } 12. gxh3 { [%clk 0:01:58] } 12... Bxg1 { [%clk 0:02:36] } 13. Rxg1 { [%clk 0:01:59] } 13... exf4 { [%clk 0:02:37] } 14. Qxf4 { [%clk 0:01:59] } 14... Ne5 { [%clk 0:02:31] } 15. O-O-O { [%clk 0:01:58] } 15... Nxc4 { [%clk 0:02:21] } 16. Nge2 { [%clk 0:01:47] } 16... Bh7 { [%clk 0:02:09] } 17. Nd4 { [%clk 0:01:45] } 17... Ne5 { [%clk 0:01:50] } 18. Ne6 { [%clk 0:01:45] } 18... Qe7 { [%clk 0:01:52] } 19. Rgf1 { [%clk 0:01:44] } 19... f5 { [%clk 0:01:33] } 20. exf5 { [%clk 0:01:32] } 20... gxf5 { [%clk 0:01:35] } 21. Rg1 { [%clk 0:01:33] } 21... Rg8 { [%clk 0:01:08] } 22. Rxg8+ { [%clk 0:01:23] } 22... Bxg8 { [%clk 0:01:10] } 23. Qxf5 { [%clk 0:01:24] } 23... Bh7 { [%clk 0:01:09] } 24. Qxh5 { [%clk 0:01:21] } 24... Nd3+ { [%clk 0:00:57] } 25. Kd2 { [%clk 0:01:15] } 25... Nxb2 { [%clk 0:00:44] } 26. Rf1 { [%clk 0:01:16] } 26... Nc4+ { [%clk 0:00:41] } 27. Kc1 { [%clk 0:01:13] } 27... b6 { [%clk 0:00:32] } 28. Rf7 { [%clk 0:01:05] } 1-0
#
# [Event "Rated Chess960 game"]
# [Site "https://lichess.org/BHQScYxP"]
# [Date "2025.10.01"]
# [Round "-"]
# [White "AlmaAzul"]
# [Black "ZaiZev"]
# [Result "1-0"]
# [UTCDate "2025.10.01"]
# [UTCTime "00:38:19"]
# [WhiteElo "1695"]
# [BlackElo "1697"]
# [WhiteRatingDiff "+6"]
# [BlackRatingDiff "-6"]
# [TimeControl "180+2"]
# [Termination "Normal"]
# [FEN "rnkbqnbr/pppppppp/8/8/8/8/PPPPPPPP/RNKBQNBR w KQkq - 0 1"]
# [SetUp "1"]
# [Variant "Chess960"]
#
# 1. e4 { [%clk 0:03:00] } 1... f6 { [%clk 0:03:00] } 2. Ng3 { [%clk 0:03:01] } 2... e5 { [%clk 0:03:01] } 3. f3 { [%clk 0:03:02] } 3... c6 { [%clk 0:03:00] } 4. d4 { [%clk 0:03:02] } 4... exd4 { [%clk 0:03:01] } 5. Bxd4 { [%clk 0:03:04] } 5... Bb6 { [%clk 0:03:02] } 6. Bxb6 { [%clk 0:03:02] } 6... axb6 { [%clk 0:03:04] } 7. Qe3 { [%clk 0:03:00] } 7... Qd8 { [%clk 0:02:59] } 8. Nf5 { [%clk 0:02:59] } 8... Qc7 { [%clk 0:02:44] } 9. Nxg7 { [%clk 0:02:57] } 9... Ne6 { [%clk 0:02:40] } 10. Nf5 { [%clk 0:02:58] } 10... Kd8 { [%clk 0:02:40] } 11. Qh6 { [%clk 0:02:47] } 11... Ng5 { [%clk 0:02:35] } 12. Qf8# { [%clk 0:02:45] } 1-0
#
# [Event "Rated Chess960 game"]
# [Site "https://lichess.org/iQAGi5e5"]
# [Date "2025.10.01"]
# [Round "-"]
# [White "coco_jamboo_yeh"]
# [Black "kianpaya"]
# [Result "1-0"]
# [UTCDate "2025.10.01"]
# [UTCTime "00:38:43"]
# [WhiteElo "1680"]
# [BlackElo "1615"]
# [WhiteRatingDiff "+34"]
# [BlackRatingDiff "-4"]
# [TimeControl "600+0"]
# [Termination "Normal"]
# [FEN "qbnnbrkr/pppppppp/8/8/8/8/PPPPPPPP/QBNNBRKR w KQkq - 0 1"]
# [SetUp "1"]
# [Variant "Chess960"]
#
# 1. c3 { [%eval -0.15] [%clk 0:10:00] } 1... f5 { [%eval 0.25] [%clk 0:10:00] } 2. f4 { [%eval 0.04] [%clk 0:09:58] } 2... b5 { [%eval 0.51] [%clk 0:09:55] } 3. Ne3 { [%eval 0.5] [%clk 0:09:44] } 3... Nd6 { [%eval 0.9] [%clk 0:09:45] } 4. b3?! { [%eval -0.09] [%clk 0:09:40] } 4... c5 { [%eval 0.01] [%clk 0:09:42] } 5. b4 { [%eval -0.41] [%clk 0:09:37] } 5... c4 { [%eval -0.22] [%clk 0:09:40] } 6. a4 { [%eval -0.31] [%clk 0:09:35] } 6... Bg6? { [%eval 1.28] [%clk 0:09:26] } 7. Nd5?? { [%eval -4.39] [%clk 0:09:16] } 7... Qxd5 { [%eval -4.42] [%clk 0:09:23] } 8. axb5 { [%eval -4.39] [%clk 0:09:11] } 8... Nxb5 { [%eval -4.06] [%clk 0:09:18] } 9. d3 { [%eval -4.02] [%clk 0:09:00] } 9... cxd3?? { [%eval 2.19] [%clk 0:09:10] } 10. Ba2 { [%eval 1.99] [%clk 0:08:53] } 1-0
#
# [Event "Rated Chess960 tournament https://lichess.org/tournament/IOJjjWS6"]
# [Site "https://lichess.org/0tI3bsFm"]
# [Date "2025.10.01"]
# [Round "-"]
# [White "IvanScArgentino"]
# [Black "maxumfirda"]
# [Result "0-1"]
# [UTCDate "2025.10.01"]
# [UTCTime "00:38:50"]
# [WhiteElo "1651"]
# [BlackElo "2181"]
# [WhiteRatingDiff "-1"]
# [BlackRatingDiff "+0"]
# [TimeControl "120+0"]
# [Termination "Time forfeit"]
# [FEN "qbrnbknr/pppppppp/8/8/8/8/PPPPPPPP/QBRNBKNR w KQkq - 0 1"]
# [SetUp "1"]
# [Variant "Chess960"]
#
# 1. b3 { [%clk 0:02:00] } 1... b6 { [%clk 0:02:00] } 2. c4 { [%clk 0:01:58] } 2... c5 { [%clk 0:01:59] } 3. e3 { [%clk 0:01:54] } 3... e6 { [%clk 0:01:57] } 4. d4 { [%clk 0:01:53] } 4... d5 { [%clk 0:01:55] } 5. cxd5 { [%clk 0:01:50] } 5... Qxd5 { [%clk 0:01:55] } 6. Nc3 { [%clk 0:01:46] } 6... Qg5 { [%clk 0:01:51] } 7. Nf3 { [%clk 0:01:45] } 7... Qe7 { [%clk 0:01:48] } 8. dxc5 { [%clk 0:01:39] } 8... Rxc5 { [%clk 0:01:47] } 9. Bd3 { [%clk 0:01:33] } 9... Nf6 { [%clk 0:01:45] } 10. O-O { [%clk 0:01:29] } 10... O-O { [%clk 0:01:43] } 11. Bd2 { [%clk 0:01:29] } 11... Bd7 { [%clk 0:01:41] } 12. Ne4 { [%clk 0:01:22] } 12... Nxe4 { [%clk 0:01:38] } 13. Bxe4 { [%clk 0:01:22] } 13... Rh5 { [%clk 0:01:36] } 14. h3 { [%clk 0:01:16] } 14... f5 { [%clk 0:01:34] } 15. Bd3 { [%clk 0:01:07] } 15... Qd6 { [%clk 0:01:31] } 16. Bc3 { [%clk 0:00:56] } 16... Qxd3 { [%clk 0:01:29] } 17. Rfd1 { [%clk 0:00:51] } 17... Qb5 { [%clk 0:01:27] } 18. Bxg7 { [%clk 0:00:50] } 18... Rf7 { [%clk 0:01:26] } 19. Bd4 { [%clk 0:00:41] } 19... Nc6 { [%clk 0:01:23] } 20. a4 { [%clk 0:00:23] } 20... Qxb3 { [%clk 0:01:21] } 21. Be5 { [%clk 0:00:15] } 21... Nxe5 { [%clk 0:01:14] } 22. Nxe5 { [%clk 0:00:15] } 22... Bxe5 { [%clk 0:01:12] } 23. Qxe5 { [%clk 0:00:15] } 23... Qxa4 { [%clk 0:01:10] } 24. Qb8+ { [%clk 0:00:13] } 24... Rf8 { [%clk 0:01:08] } 25. Qc7 { [%clk 0:00:12] } 25... Be8 { [%clk 0:01:04] } 26. Qg3+ { [%clk 0:00:10] } 26... Bg6 { [%clk 0:01:00] } 27. Rd4 { [%clk 0:00:09] } 27... Qa3 { [%clk 0:00:58] } 28. Rcd1 { [%clk 0:00:09] } 28... f4 { [%clk 0:00:55] } 29. Qg4 { [%clk 0:00:07] } 29... Rhf5 { [%clk 0:00:53] } 30. exf4 { [%clk 0:00:06] } 30... Qe7 { [%clk 0:00:51] } 31. h4 { [%clk 0:00:05] } 31... Qg7 { [%clk 0:00:48] } 32. h5 { [%clk 0:00:04] } 32... Bxh5 { [%clk 0:00:46] } 33. Qxh5 { [%clk 0:00:04] } 33... Rxh5 { [%clk 0:00:45] } 34. g3 { [%clk 0:00:03] } 34... a5 { [%clk 0:00:43] } 35. Rd7 { [%clk 0:00:02] } 35... Qf6 { [%clk 0:00:41] } 36. Rc1 { [%clk 0:00:01] } 36... b5 { [%clk 0:00:40] } 37. Rcc7 { [%clk 0:00:01] } 37... b4 { [%clk 0:00:39] } 38. Rxh7 { [%clk 0:00:00] } 38... Rxh7 { [%clk 0:00:37] } 0-1
#
# [Event "Rated Chess960 tournament https://lichess.org/tournament/IOJjjWS6"]
# [Site "https://lichess.org/JYWPveJg"]
# [Date "2025.10.01"]
# [Round "-"]
# [White "stroto"]
# [Black "Leandrocabj"]
# [Result "1-0"]
# [UTCDate "2025.10.01"]
# [UTCTime "00:38:50"]
# [WhiteElo "1527"]
# [BlackElo "1493"]
# [WhiteRatingDiff "+73"]
# [BlackRatingDiff "-92"]
# [TimeControl "120+0"]
# [Termination "Normal"]
# [FEN "rbqknrbn/pppppppp/8/8/8/8/PPPPPPPP/RBQKNRBN w KQkq - 0 1"]
# [SetUp "1"]
# [Variant "Chess960"]
#
# 1. f4 { [%clk 0:02:00] } 1... c6 { [%clk 0:02:00] } 2. c3 { [%clk 0:01:58] } 2... Nd6 { [%clk 0:01:58] } 3. e4 { [%clk 0:01:57] } 3... f6 { [%clk 0:01:57] } 4. d4 { [%clk 0:01:55] } 4... e6 { [%clk 0:01:55] } 5. Ng3 { [%clk 0:01:55] } 5... a6 { [%clk 0:01:51] } 6. Be3 { [%clk 0:01:53] } 6... Nhf7 { [%clk 0:01:49] } 7. Nf3 { [%clk 0:01:52] } 7... h6 { [%clk 0:01:47] } 8. O-O { [%clk 0:01:51] } 8... Bh7 { [%clk 0:01:46] } 9. e5 { [%clk 0:01:49] } 9... Bxb1 { [%clk 0:01:45] } 10. Qxb1 { [%clk 0:01:49] } 10... Nc4 { [%clk 0:01:42] } 11. Bf2 { [%clk 0:01:43] } 11... d5 { [%clk 0:01:40] } 12. b3 { [%clk 0:01:42] } 12... Nb6 { [%clk 0:01:37] } 13. Qg6 { [%clk 0:01:41] } 13... Qd7 { [%clk 0:01:32] } 14. Qxg7 { [%clk 0:01:39] } 14... Bc7 { [%clk 0:01:30] } 15. Qxf8+ { [%clk 0:01:38] } 1-0
#
# [Event "Rated Chess960 game"]
# [Site "https://lichess.org/fLin0pL3"]
# [Date "2025.10.01"]
# [Round "-"]
# [White "paparoach"]
# [Black "Blindcatkelevra"]
# [Result "0-1"]
# [UTCDate "2025.10.01"]
# [UTCTime "00:39:05"]
# [WhiteElo "1978"]
# [BlackElo "2061"]
# [WhiteRatingDiff "-5"]
# [BlackRatingDiff "+6"]
# [TimeControl "30+1"]
# [Termination "Time forfeit"]
# [FEN "bbrqnnkr/pppppppp/8/8/8/8/PPPPPPPP/BBRQNNKR w KQkq - 0 1"]
# [SetUp "1"]
# [Variant "Chess960"]
#
# 1. Ng3 { [%clk 0:00:30] } 1... d5 { [%clk 0:00:30] } 2. O-O { [%clk 0:00:31] } 2... c5 { [%clk 0:00:30] } 3. b3 { [%clk 0:00:31] } 3... e5 { [%clk 0:00:30] } 4. e3 { [%clk 0:00:31] } 4... Ng6 { [%clk 0:00:30] } 5. d4 { [%clk 0:00:31] } 5... cxd4 { [%clk 0:00:30] } 6. exd4 { [%clk 0:00:32] } 6... e4 { [%clk 0:00:30] } 7. c4 { [%clk 0:00:32] } 7... dxc4 { [%clk 0:00:25] } 8. bxc4 { [%clk 0:00:33] } 8... f5 { [%clk 0:00:20] } 9. Nxf5 { [%clk 0:00:31] } 9... b6 { [%clk 0:00:20] } 10. d5 { [%clk 0:00:31] } 10... O-O { [%clk 0:00:19] } 11. Ng3 { [%clk 0:00:24] } 11... Nd6 { [%clk 0:00:18] } 12. Nxe4 { [%clk 0:00:21] } 12... Nxc4 { [%clk 0:00:16] } 13. Qd4 { [%clk 0:00:17] } 13... Be5 { [%clk 0:00:12] } 14. Rxc4 { [%clk 0:00:06] } 14... Bxd4 { [%clk 0:00:11] } 15. Rxd4 { [%clk 0:00:07] } 15... Qd7 { [%clk 0:00:04] } 16. Nf3 { [%clk 0:00:05] } 16... Rce8 { [%clk 0:00:04] } 17. Neg5 { [%clk 0:00:05] } 17... h6 { [%clk 0:00:04] } 18. Ne6 { [%clk 0:00:04] } 18... Rf6 { [%clk 0:00:03] } 19. Rg4 { [%clk 0:00:03] } 19... Bxd5 { [%clk 0:00:03] } 0-1
#
# [Event "Rated Chess960 game"]
# [Site "https://lichess.org/BFHvvQqd"]
# [Date "2025.10.01"]
# [Round "-"]
# [White "hungryhipposs"]
# [Black "AboOmar10"]
# [Result "1-0"]
# [UTCDate "2025.10.01"]
# [UTCTime "00:39:49"]
# [WhiteElo "1878"]
# [BlackElo "1851"]
# [WhiteRatingDiff "+5"]
# [BlackRatingDiff "-18"]
# [TimeControl "180+0"]
# [Termination "Normal"]
# [FEN "qrknrbbn/pppppppp/8/8/8/8/PPPPPPPP/QRKNRBBN w KQkq - 0 1"]
# [SetUp "1"]
# [Variant "Chess960"]
#
# 1. e4 { [%clk 0:03:00] } 1... b5 { [%clk 0:03:00] } 2. f4 { [%clk 0:02:57] } 2... g6 { [%clk 0:02:57] } 3. g3 { [%clk 0:02:53] } 3... Bg7 { [%clk 0:02:55] } 4. d4 { [%clk 0:02:53] } 4... f5 { [%clk 0:02:52] } 5. e5 { [%clk 0:02:52] } 5... Qxh1 { [%clk 0:02:50] } 6. Ne3 { [%clk 0:02:45] } 6... Qb7 { [%clk 0:02:45] } 7. a4 { [%clk 0:02:44] } 7... b4 { [%clk 0:02:41] } 8. a5 { [%clk 0:02:43] } 8... a6 { [%clk 0:02:38] } 9. Bg2 { [%clk 0:02:40] } 9... Qa7 { [%clk 0:02:35] } 10. Qa4 { [%clk 0:02:38] } 10... Ne6 { [%clk 0:02:17] } 11. d5 { [%clk 0:02:36] } 11... Nc5 { [%clk 0:02:15] } 12. Qa2 { [%clk 0:02:32] } 12... c6 { [%clk 0:02:11] } 13. O-O-O { [%clk 0:02:26] } 13... b3 { [%clk 0:02:05] } 14. Qa3 { [%clk 0:02:24] } 14... bxc2 { [%clk 0:01:56] } 15. Nxc2 { [%clk 0:02:23] } 15... Nb3+ { [%clk 0:01:52] } 16. Qxb3 { [%clk 0:02:20] } 16... Rxb3 { [%clk 0:01:45] } 17. Bxa7 { [%clk 0:02:19] } 17... cxd5 { [%clk 0:01:24] } 18. Bxd5 { [%clk 0:02:19] } 18... Bxd5 { [%clk 0:01:22] } 19. Rxd5 { [%clk 0:02:19] } 19... d6 { [%clk 0:01:20] } 20. exd6 { [%clk 0:02:11] } 20... Bxb2+ { [%clk 0:01:17] } 21. Kd1 { [%clk 0:02:09] } 21... Kd7 { [%clk 0:00:47] } 22. dxe7+ { [%clk 0:02:04] } 22... Kc6 { [%clk 0:00:43] } 23. Rd8 { [%clk 0:02:00] } 1-0
#
# [Event "Rated Chess960 tournament https://lichess.org/tournament/IOJjjWS6"]
# [Site "https://lichess.org/UzmxAOM1"]
# [Date "2025.10.01"]
# [Round "-"]
# [White "d4nis-bkd"]
# [Black "stroto"]
# [Result "1-0"]
# [UTCDate "2025.10.01"]
# [UTCTime "00:40:07"]
# [WhiteElo "1919"]
# [BlackElo "1600"]
# [WhiteRatingDiff "+1"]
# [BlackRatingDiff "-24"]
# [TimeControl "120+0"]
# [Termination "Time forfeit"]
# [FEN "nqrbnkbr/pppppppp/8/8/8/8/PPPPPPPP/NQRBNKBR w KQkq - 0 1"]
# [SetUp "1"]
# [Variant "Chess960"]
#
# 1. f3 { [%clk 0:02:00] } 1... c5 { [%clk 0:02:00] } 2. e4 { [%clk 0:01:58] } 2... Nb6 { [%clk 0:01:59] } 3. Be3 { [%clk 0:01:54] } 3... d5 { [%clk 0:01:57] } 4. d3 { [%clk 0:01:51] } 4... d4 { [%clk 0:01:49] } 5. Bd2 { [%clk 0:01:49] } 5... e5 { [%clk 0:01:47] } 6. O-O { [%clk 0:01:48] } 6... f6 { [%clk 0:01:45] } 7. c3 { [%clk 0:01:47] } 7... Be6 { [%clk 0:01:42] } 8. cxd4 { [%clk 0:01:45] } 8... cxd4 { [%clk 0:01:42] } 9. Rxc8 { [%clk 0:01:43] } 9... Qxc8 { [%clk 0:01:42] } 10. a4 { [%clk 0:01:42] } 10... O-O { [%clk 0:01:36] } 11. a5 { [%clk 0:01:40] } 11... Nd7 { [%clk 0:01:35] } 12. b4 { [%clk 0:01:39] } 12... Be7 { [%clk 0:01:29] } 13. Bb3 { [%clk 0:01:38] } 13... Nb8 { [%clk 0:01:21] } 14. g3 { [%clk 0:01:31] } 14... Nd6 { [%clk 0:01:11] } 15. Ng2 { [%clk 0:01:26] } 15... Nb5 { [%clk 0:01:09] } 16. Rc1 { [%clk 0:01:23] } 16... Qd7 { [%clk 0:01:07] } 17. Qa2 { [%clk 0:01:21] } 17... Kf7 { [%clk 0:01:06] } 18. f4 { [%clk 0:01:19] } 18... Rc8 { [%clk 0:01:04] } 19. fxe5 { [%clk 0:01:14] } 19... Rxc1+ { [%clk 0:01:02] } 20. Bxc1 { [%clk 0:01:14] } 20... fxe5 { [%clk 0:01:01] } 21. Bd2 { [%clk 0:01:09] } 21... Nc6 { [%clk 0:00:59] } 22. Nc2 { [%clk 0:01:07] } 22... Qd6 { [%clk 0:00:52] } 23. Nge1 { [%clk 0:00:58] } 23... h6 { [%clk 0:00:48] } 24. Nf3 { [%clk 0:00:54] } 24... Bxb3 { [%clk 0:00:44] } 25. Qxb3+ { [%clk 0:00:53] } 25... Qe6 { [%clk 0:00:44] } 26. Qc4 { [%clk 0:00:47] } 26... a6 { [%clk 0:00:37] } 27. Qd5 { [%clk 0:00:46] } 27... Bd6 { [%clk 0:00:11] } 28. Kg2 { [%clk 0:00:45] } 28... Nc7 { [%clk 0:00:08] } 29. Qc4 { [%clk 0:00:40] } 29... Qxc4 { [%clk 0:00:06] } 30. dxc4 { [%clk 0:00:40] } 30... Ne6 { [%clk 0:00:04] } 31. b5 { [%clk 0:00:37] } 31... axb5 { [%clk 0:00:03] } 32. cxb5 { [%clk 0:00:36] } 32... Na7 { [%clk 0:00:03] } 33. b6 { [%clk 0:00:32] } 33... Nc6 { [%clk 0:00:01] } 34. Nce1 { [%clk 0:00:30] } 1-0
#
# [Event "Rated Chess960 tournament https://lichess.org/tournament/IOJjjWS6"]
# [Site "https://lichess.org/TSZl8ADc"]
# [Date "2025.10.01"]
# [Round "-"]
# [White "KAPOKNYAKAPAN_PMAN"]
# [Black "MarrecoVoltaLance"]
# [Result "0-1"]
# [UTCDate "2025.10.01"]
# [UTCTime "00:40:07"]
# [WhiteElo "1801"]
# [BlackElo "1706"]
# [WhiteRatingDiff "-12"]
# [BlackRatingDiff "+7"]
# [TimeControl "120+0"]
# [Termination "Time forfeit"]
# [FEN "qrbbnkrn/pppppppp/8/8/8/8/PPPPPPPP/QRBBNKRN w KQkq - 0 1"]
# [SetUp "1"]
# [Variant "Chess960"]
#
# 1. e4 { [%clk 0:01:00] } 1... Ng6 { [%clk 0:02:00] } 2. Ng3 { [%clk 0:01:00] } 2... d6 { [%clk 0:02:00] } 3. Nf3 { [%clk 0:00:57] } 3... e5 { [%clk 0:01:59] } 4. O-O { [%clk 0:00:56] } 4... Nf6 { [%clk 0:01:58] } 5. d4 { [%clk 0:00:55] } 5... exd4 { [%clk 0:01:55] } 6. Nxd4 { [%clk 0:00:53] } 6... O-O { [%clk 0:01:53] } 7. Be3 { [%clk 0:00:53] } 7... c5 { [%clk 0:01:51] } 8. Ndf5 { [%clk 0:00:52] } 8... Bxf5 { [%clk 0:01:49] } 9. exf5 { [%clk 0:00:51] } 9... Ne5 { [%clk 0:01:47] } 10. b3 { [%clk 0:00:46] } 10... Rc8 { [%clk 0:01:43] } 11. Be2 { [%clk 0:00:43] } 11... b5 { [%clk 0:01:41] } 12. Rbd1 { [%clk 0:00:41] } 12... Qb8 { [%clk 0:01:34] } 13. Bg5 { [%clk 0:00:37] } 13... h6 { [%clk 0:01:32] } 14. Bh4 { [%clk 0:00:34] } 14... Nfg4 { [%clk 0:01:24] } 15. Bxd8 { [%clk 0:00:31] } 15... Rcxd8 { [%clk 0:01:23] } 16. Bxg4 { [%clk 0:00:28] } 16... Nxg4 { [%clk 0:01:23] } 17. Nh5 { [%clk 0:00:28] } 17... f6 { [%clk 0:01:19] } 18. f4 { [%clk 0:00:25] } 18... Ne3 { [%clk 0:01:17] } 19. Rf3 { [%clk 0:00:23] } 19... Nxd1 { [%clk 0:01:16] } 20. Qxd1 { [%clk 0:00:22] } 20... Rde8 { [%clk 0:01:15] } 21. Rg3 { [%clk 0:00:21] } 21... Rf7 { [%clk 0:01:12] } 22. Qg4 { [%clk 0:00:19] } 22... Qc7 { [%clk
[%clk 0:00:15] } 32. Kf2 { [%clk 0:00:10] } 32... Kg7 { [%clk 0:00:12] } 33. Ke3 { [%clk 0:00:08] } 33... Bxf3 { [%clk 0:00:13] } 34. Kxf3 { [%clk 0:00:08] } 34... Rd4 { [%clk 0:00:15] } 35. Rc4 { [%clk 0:00:10] } 35... Rd7 { [%clk 0:00:13] } 36. Rc6 { [%clk 0:00:11] } 36... Rb7 { [%clk 0:00:12] } 37. g4 { [%clk 0:00:10] } 37... b5 { [%clk 0:00:11] } 38. gxf5 { [%clk 0:00:10] } 38... Rf7 { [%clk 0:00:12] } 39. f6+ { [%clk 0:00:10] } 1-0
#
# [Event "Rated Chess960 game"]
# [Site "https://lichess.org/szrmvYqW"]
# [Date "2025.10.01"]
# [Round "-"]
# [White "Alexlei2015"]
# [Black "eltigredebejucal77"]
# [Result "0-1"]
# [UTCDate "2025.10.01"]
# [UTCTime "00:40:48"]
# [WhiteElo "1284"]
# [BlackElo "1279"]
# [WhiteRatingDiff "-144"]
# [BlackRatingDiff "+5"]
# [TimeControl "600+0"]
# [Termination "Normal"]
# [FEN "nnbrqbkr/pppppppp/8/8/8/8/PPPPPPPP/NNBRQBKR w KQkq - 0 1"]
# [SetUp "1"]
# [Variant "Chess960"]
#
# 1. d4 { [%clk 0:10:00] } 1... e5 { [%clk 0:10:00] } 2. Qc3 { [%clk 0:09:54] } 2... Bd6 { [%clk 0:09:53] } 3. dxe5 { [%clk 0:09:51] } 3... Bxe5 { [%clk 0:09:46] } 4. g3 { [%clk 0:09:51] } 4... Bxc3 { [%clk 0:09:43] } 5. Bg2 { [%clk 0:09:49] } 5... Bf6 { [%clk 0:09:39] } 6. Nc3 { [%clk 0:09:49] } 6... Bxc3 { [%clk 0:09:37] } 7. O-O { [%clk 0:09:48] } 7... Bf6 { [%clk 0:09:34] } 0-1
#
# [Event "Rated Chess960 game"]
# [Site "https://lichess.org/jQP7zyjf"]
# [Date "2025.10.01"]
# [Round "-"]
# [White "Blindcatkelevra"]
# [Black "paparoach"]
# [Result "1-0"]
# [UTCDate "2025.10.01"]
# [UTCTime "00:40:49"]
# [WhiteElo "2067"]
# [BlackElo "1973"]
# [WhiteRatingDiff "+7"]
# [BlackRatingDiff "-4"]
# [TimeControl "30+1"]
# [Termination "Normal"]
# [FEN "nnrqkrbb/pppppppp/8/8/8/8/PPPPPPPP/NNRQKRBB w KQkq - 0 1"]
# [SetUp "1"]
# [Variant "Chess960"]
#
# 1. g3 { [%clk 0:00:30] } 1... Nc6 { [%clk 0:00:30] } 2. f4 { [%clk 0:00:31] } 2... Nb6 { [%clk 0:00:30] } 3. Nb3 { [%clk 0:00:31] } 3... g6 { [%clk 0:00:31] } 4. Nc3 { [%clk 0:00:32] } 4... Nc4 { [%clk 0:00:30] } 5. Rb1 { [%clk 0:00:31] } 5... f5 { [%clk 0:00:27] } 6. d3 { [%clk 0:00:32] } 6... Nxb2 { [%clk 0:00:25] } 7. Qc1 { [%clk 0:00:26] } 7... Bxc3+ { [%clk 0:00:25] } 8. Nd2 { [%clk 0:00:27] } 8... Bxa2 { [%clk 0:00:18] } 9. Rxb2 { [%clk 0:00:27] } 9... Bxb2 { [%clk 0:00:18] } 10. Qxb2 { [%clk 0:00:28] } 10... Bf7 { [%clk 0:00:18] } 11. Qxb7 { [%clk 0:00:27] } 11... Rb8 { [%clk 0:00:17] } 12. Qa6 { [%clk 0:00:26] } 12... O-O { [%clk 0:00:15] } 13. Bxc6 { [%clk 0:00:26] } 13... dxc6 { [%clk 0:00:15] } 14. Qxc
#
# [Event "Rated Chess960 tournament https://lichess.org/tournament/IOJjjWS6"]
# [Site "https://lichess.org/izjl9YkJ"]
# [Date "2025.10.01"]
# [Round "-"]
# [White "Jus_Jacome"]
# [Black "lechoza-verde"]
# [Result "0-1"]
# [UTCDate "2025.10.01"]
# [UTCTime "00:41:24"]
# [WhiteElo "2143"]
# [BlackElo "1977"]
# [WhiteRatingDiff "-8"]
# [BlackRatingDiff "+8"]
# [TimeControl "120+0"]
# [Termination "Normal"]
# [FEN "rqbknnrb/pppppppp/8/8/8/8/PPPPPPPP/RQBKNNRB w KQkq - 0 1"]
# [SetUp "1"]
# [Variant "Chess960"]
#
# 1. e4 { [%clk 0:02:00] } 1... g6 { [%clk 0:02:00] } 2. f4 { [%clk 0:01:58] } 2... d6 { [%clk 0:01:58] } 3. Nf3 { [%clk 0:01:57] } 3... Nf6 { [%clk 0:01:56] } 4. d3 { [%clk 0:01:55] } 4... Bg7 { [%clk 0:01:53] } 5. Ne3 { [%clk 0:01:55] } 5... h6 { [%clk 0:01:50] } 6. O-O { [%clk 0:01:53] } 6... Ne6 { [%clk 0:01:49] } 7. g3 { [%clk 0:01:52] } 7... c5 { [%clk 0:01:46] } 8. c3 { [%clk 0:01:50] } 8... O-O { [%clk 0:01:44] } 9. Qc2 { [%clk 0:01:49] } 9... b5 { [%clk 0:01:43] } 10. f5 { [%clk 0:01:48] } 10... Nc7 { [%clk 0:01:35] } 11. fxg6 { [%clk 0:01:47] } 11... fxg6 { [%clk 0:01:35] } 12. Nh4 { [%clk 0:01:46] } 12... g5 { [%clk 0:01:32] } 13. Ng6 { [%clk 0:01:45] } 13... Rf7 { [%clk 0:01:31] } 14. e5 { [%clk 0:01:43] } 14... dxe5 { [%clk 0:01:30] } 15. Qb3 { [%clk 0:01:37] } 15... Be6 { [%clk 0:01:26] } 16. Qa3 { [%clk 0:01:31] } 16... b4 { [%clk 0:01:23] } 17. Qa5 { [%clk 0:01:29] } 17... Kh7 { [%clk 0:01:20] } 18. Nxe5 { [%clk 0:01:24] } 18... Rf8 { [%clk 0:01:19] } 19. Nc6 { [%clk 0:01:21] } 19... Qb6 { [%clk 0:01:16] } 20. Qxb6 { [%clk 0:01:20] } 20... axb6 { [%clk 0:01:16] } 21. Nxe7 { [%clk 0:01:19] } 21... Rae8 { [%clk 0:01:15] } 22. Nc6 { [%clk 0:01:18] } 22... Nfd5 { [%clk 0:01:12] } 23. Nxd5 { [%clk 0:01:17] } 23... Bxd5 { [%clk 0:01:08] } 24. Bxd5 { [%clk 0:01:15] } 24... Rxf1+ { [%clk 0:01:06] } 25. Kxf1 { [%clk 0:01:14] } 25... Nxd5 { [%clk 0:01:06] } 26. Bd2 { [%clk 0:01:10] } 26... Re6 { [%clk 0:01:03] } 27. Na7 { [%clk 0:01:06] } 27... bxc3 { [%clk 0:01:01] } 28. bxc3 { [%clk 0:01:06] } 28... Nxc3 { [%clk 0:00:59] } 29. Re1 { [%clk 0:01:03] } 29... Rxe1+ { [%clk 0:00:56] } 30. Kxe1 { [%clk 0:01:02] } 30... Nxa2 { [%clk 0:00:56] } 31. Nc6 { [%clk 0:01:01] } 31... Nc3 { [%clk 0:00:55] } 32. Bxc3 { [%clk 0:00:56] } 32... Bxc3+ { [%clk 0:00:55] } 33. Kd1 { [%clk 0:00:56] } 33... b5 { [%clk 0:00:53] } 34. Kc2 { [%clk 0:00:55] } 34... b4 { [%clk 0:00:53] } 35. Kb3 { [%clk 0:00:54] } 35... Kg6 { [%clk 0:00:51] } 36. g4 { [%clk 0:00:53] } 36... Be1 { [%clk 0:00:47] } 37. Kc4 { [%clk 0:00:52] } 37... Bf2 { [%clk 0:00:46] } 38. h3 { [%clk 0:00:51] } 38... h5 { [%clk 0:00:45] } 39. Ne5+ { [%clk 0:00:50] } 39... Kf6 { [%clk 0:00:43] } 40. Nd7+ { [%clk 0:00:49] } 40... Ke6 { [%clk 0:00:42] } 41. Nxc5+ { [%clk 0:00:46] } 41... Bxc5 { [%clk 0:00:41] } 42. gxh5 { [%clk 0:00:45] } 42... Bf8 { [%clk 0:00:39] } 43. d4 { [%clk 0:00:44] } 43... Kf5 { [%clk 0:00:34] } 44. h6 { [%clk 0:00:42] } 44... Kg6 { [%clk 0:00:33] } 45. d5 { [%clk 0:00:40] } 45... Kxh6 { [%clk 0:00:32] } 46. Kd4 { [%clk 0:00:39] } 46... Kh5 { [%clk 0:00:31] } 47. Ke5 { [%clk 0:00:37] } 47... b3 { [%clk 0:00:30] } 48. d6 { [%clk 0:00:37] } 48... b2 { [%clk 0:00:29] } 49. d7 { [%clk 0:00:36] } 49... Be7 { [%clk 0:00:29] } 50. Ke6 { [%clk 0:00:35] } 50... Bd8 { [%clk 0:00:28] } 51. Kf7 { [%clk 0:00:34] } 51... b1=Q { [%clk 0:00:28] } 52. Ke8 { [%clk 0:00:34] } 52... Qb6 { [%clk 0:00:27] } 53. Kf7 { [%clk 0:00:31] } 53... Qd6 { [%clk 0:00:25] } 54. Ke8 { [%clk 0:00:31] } 54... Qe7# { [%clk 0:00:25] } 0-1
#
# [Event "Rated Chess960 tournament https://lichess.org/tournament/IOJjjWS6"]
# [Site "https://lichess.org/x7DRNC8b"]
# [Date "2025.10.01"]
# [Round "-"]
# [White "ProfThiago"]
# [Black "Olivetreeb"]
# [Result "1-0"]
# [UTCDate "2025.10.01"]
# [UTCTime "00:41:24"]
# [WhiteElo "1992"]
# [BlackElo "1168"]
# [WhiteRatingDiff "+0"]
# [BlackRatingDiff "+0"]
# [TimeControl "120+0"]
# [Termination "Time forfeit"]
# [FEN "qnrknbbr/pppppppp/8/8/8/8/PPPPPPPP/QNRKNBBR w KQkq - 0 1"]
# [SetUp "1"]
# [Variant "Chess960"]
#
# 1. g3 { [%clk 0:01:00] } 1... a5 { [%clk 0:02:00] } 2. Nf3 { [%clk 0:01:00] } 2... a4 { [%clk 0:01:56] } 3. Bg2 { [%clk 0:01:00] } 3... b6 { [%clk 0:01:44] } 4. b3 { [%clk 0:00:59] } 4... axb3 { [%clk 0:01:38] } 5. cxb3 { [%clk 0:00:59] } 5... f6 { [%clk 0:01:33] } 6. Nh4
:40] } 20. Rgf1 { [%clk 0:01:28] } 20... Rac8 { [%clk 0:02:36] } 21. Qb3 { [%clk 0:00:53] } 21... Rgf8 { [%clk 0:02:15] } 22. Nxd5 { [%clk 0:00:43] } 22... Kb8 { [%clk 0:02:06] } 23. Rxf7 { [%clk 0:00:26] } 23... Rxf7 { [%clk 0:01:59] } 24. Nxb6 { [%clk 0:00:25] } 24... Nxd3+ { [%clk 0:01:03] } 25. Kb1 { [%clk 0:00:06] } 25... Qd4 { [%clk 0:00:30] } 0-1
#
# [Event "Rated Chess960 game"]
# [Site "https://lichess.org/SB0EYNbv"]
# [Date "2025.10.01"]
# [Round "-"]
# [White "Ridhaan6"]
# [Black "Springers11"]
# [Result "0-1"]
# [UTCDate "2025.10.01"]
# [UTCTime "00:41:38"]
# [WhiteElo "1722"]
# [BlackElo "1811"]
# [WhiteRatingDiff "-12"]
# [BlackRatingDiff "+7"]
# [TimeControl "60+0"]
# [Termination "Normal"]
# [FEN "rbnkbqnr/pppppppp/8/8/8/8/PPPPPPPP/RBNKBQNR w KQkq - 0 1"]
# [SetUp "1"]
# [Variant "Chess960"]
#
# 1. Nf3 { [%clk 0:01:00] } 1... e5 { [%clk 0:01:00] } 2. g3 { [%clk 0:01:00] } 2... e4 { [%clk 0:01:00] } 3. Nd4 { [%clk 0:00:58] } 3... Nd6 { [%clk 0:00:58] } 4. Ndb3 { [%clk 0:00:58] } 4... f6 { [%clk 0:00:56] } 5. c3 { [%clk 0:00:58] } 5... Bf7 { [%clk 0:00:55] } 6. Qg2 { [%clk 0:00:57] } 6... Bxb3+ { [%clk 0:00:55] } 7. Nxb3 { [%clk 0:00:55] } 7... b6 { [%clk 0:00:53] } 8. Bxe4 { [%clk 0:00:54] } 8... Nxe4 { [%clk 0:00:51] } 9. Qxe4 { [%clk 0:00:52] } 9... c6 { [%clk 0:00:49] } 10. d4 { [%clk 0:00:51] } 10... Qe7 { [%clk 0:00:48] } 11. Qxe7+ { [%clk 0:00:50] } 11... Nxe7 { [%clk 0:00:48] } 12. e4 { [%clk 0:00:49] } 12... O-O { [%clk 0:00:45] } 13. f3 { [%clk 0:00:49] } 13... Ng6 { [%clk 0:00:44] } 14. Bf2 { [%clk 0:00:49] } 14... d5 { [%clk 0:00:43] } 15. O-O-O { [%clk 0:00:47] } 15... dxe4 { [%clk 0:00:42] } 16. fxe4 { [%clk 0:00:46] } 16... Re8 { [%clk 0:00:40] } 17. Rde1 { [%clk 0:00:46] } 17... Bc7 { [%clk 0:00:38] } 18. Re2 { [%clk 0:00:45] } 18... Rad8 { [%clk 0:00:37] } 19. Rhe1 { [%clk 0:00:44] } 19... c5 { [%clk 0:00:36] } 20. dxc5 { [%clk 0:00:42] } 20... bxc5 { [%clk 0:00:36] } 21. Nxc5 { [%clk 0:00:41] } 21... Bb6 { [%clk 0:00:35] } 22. Nb7 { [%clk 0:00:39] } 22... Bxf2 { [%clk 0:00:34] } 23. Nxd8 { [%clk 0:00:38] } 23... Bxe1 { [%clk 0:00:33] } 24. Rxe1 { [%clk 0:00:35] } 24... Rxd8 { [%clk 0:00:32] } 25. Kc2 { [%clk 0:00:34] } 25... Kf7 { [%clk 0:00:31] } 26. Kb3 { [%clk 0:00:34] } 26... Ne5 { [%clk 0:00:30] } 27. Kb4 { [%clk 0:00:34] } 27... Nd3+ { [%clk 0:00:30] } 28. Kb5 { [%clk 0:00:34] } 28... Nxe1 { [%clk 0:00:29] } 29. Ka6 { [%clk 0:00:33] } 29... Rd2 { [%clk 0:00:28] } 30. Kxa7 { [%clk 0:00:33] } 30... Rxb2 { [%clk 0:00:27] } 31. Ka8 { [%clk 0:00:30] } 31... Rxa2+ { [%clk 0:00:27] } 32. Kb8 { [%clk 0:00:30] } 32... Rxh2 { [%clk 0:00:26] } 33. Kc8 { [%clk 0:00:30] } 33... Rh3 { [%clk 0:00:26] } 34. Kc7 { [%clk 0:00:28] } 34... Rxg3 { [%clk 0:00:26] } 35. Kb8 { [%clk 0:00:28] } 35... Rxc3 { [%clk 0:00:25] } 36. Kb7 { [%clk 0:00:28] } 36... Rc4 { [%clk 0:00:24] } 37. Kb6 { [%clk 0:00:27] } 37... Rxe4 { [%clk 0:00:24] } 38. Kb5 { [%clk 0:00:27] } 38... Re5+ { [%clk 0:00:24] } 39. Kc6 { [%clk 0:00:27] } 39... g5 { [%clk 0:00:23] } 40. Kb6 { [%clk 0:00:27] } 40... g4 { [%clk 0:00:23] } 41. Kc7 { [%clk 0:00:27] } 41... g3 { [%clk 0:00:23] } 42. Kb7 { [%clk 0:00:27] } 42... g2 { [%clk 0:00:23] } 43. Kc8 { [%clk 0:00:27] } 43... g1=Q { [%clk 0:00:22] } 44. Kd8 { [%clk 0:00:26] } 44... Nf3 { [%clk 0:00:22] } 45. Kc7 { [%clk 0:00:26] } 45... Qd1 { [%clk 0:00:22] } 46. Kc8 { [%clk 0:00:26] } 46... Re2 { [%clk 0:00:21] } 47. Kb8 { [%clk 0:00:26] } 47... Rc2 { [%clk 0:00:21] } 48. Kb7 { [%clk 0:00:26] } 48... Qb1+ { [%clk 0:00:21] } 49. Ka7 { [%clk 0:00:25] } 49... Ra2# { [%clk 0:00:21] } 0-1
#
# [Event "Rated Chess960 game"]
# [Site "https://lichess.org/ge5CvfVt"]
# [Date "2025.10.01"]
# [Round "-"]
# [White "RuyLopez101"]
# [Black "AlmaAzul"]
# [Result "1-0"]
# [UTCDate "2025.10.01"]
# [UTCTime "00:41:44"]
# [WhiteElo "1756"]
# [BlackElo "1701"]
# [WhiteRatingDiff "+5"]
# [BlackRatingDiff "-5"]
# [TimeControl "300+0"]
# [Termination "Normal"]
# [FEN "nbbrnqkr/pppppppp/8/8/8/8/PPPPPPPP/NBBRNQKR w KQkq - 0 1"]
# [SetUp "1"]

# %%
def parse_key_value(string):
    key, value = string.strip()[1:-1].split(maxsplit=1)
    return key, value[1:-1]

def parse_moves(string):
    tokens = string.split()
    moves = [token for token in tokens if token[0].isalpha()]
    evals = [token[:-1] for token in tokens if token.endswith("]") and "." in token]
    clock = [token[:-1] for token in tokens if (len(token) == 8 and token[1] == token[4] == ":")]
    return moves, evals, clock

def get_next_game():
    game = {}
    while True:
        line = f.readline()
        if line == "":
            raise Exception()
        elif line == "\n":
            continue
        elif line.startswith("["):
            key, value = parse_key_value(line)
            game[key] = value
        elif line.startswith("1."):
            moves, evals, clock = parse_moves(line)
            game["Moves"] = moves
            game["Evals"] = evals
            game["Clock"] = clock
            return game

# %%
get_next_game()

# %%
class FilePGN:

    def parse(self, game):
        moves = [
            string
            for string in game
            if string[0].isalpha()
        ]

        moves = [
            self.parse_pgn_move(move, self.get_side(k))
            for k, move in enumerate(moves)
        ]

        return moves

    @staticmethod
    def get_side(k):
        if k % 2 == 0:
            return "w"
        else:
            return "b"

    @staticmethod
    def parse_pgn_move(move, side):

        move = move.translate(str.maketrans("", "", "x=+#?!"))

        if (move == "O-O"):
            move = {"w": "Ke1g1", "b": "Ke8g8"}[side]
        if (move == "O-O-O"):
            move = {"w": "Ke1c1", "b": "Ke8c8"}[side]

        if move[0].isupper():
            piece, move = move[0], move[1:]
        else:
            piece = "p"

        if move[-1].isupper():
            promotion_to, move = move[-1], move[:-1]
        else:
            promotion_to = ""

        piece = piece.lower()
        promotion_to = promotion_to.lower()

        to_square = move[-2:]
        disambig = move[:-2]

        return (side, piece, disambig, to_square, promotion_to)

parser_moves = FilePGN()

# %%
stockfish = Stockfish("stockfish/stockfish-windows-x86-64-avx2.exe")

# %%
PGN_FILE = "pgn/lichess_db_standard_rated_2018-06.pgn"
print(f"PGN file size (bytes): {getsize(PGN_FILE):,}")

f = open(PGN_FILE, mode="r")

# %%
def get_data():

    big_df = pd.DataFrame()#columns=["K", "Q", "R", "B", "N", "P", "k", "q", "r", "b", "n", "p"])
    for i in range(10_000):
        print(i, end="\r")
        a = get_next_analysed_game()
        a = a.replace("[", "").replace("]", "")
        a = a.split()
        
        moves = a[1::8]
        evals = a[4::8]
        
        if moves[-1].endswith("#"):
            moves = moves[:-1]
            evals = evals[:-1]
        
        moves = moves[:200]
        evals = evals[:200]
        
        moves = parser_moves.parse(moves)
        
        stockfish.start_new_game()
        d = []
        for move_number, move in enumerate(moves, start=1):
            stockfish.make_pgn_move(move)
            d.append(list(stockfish.pieces_count))
        
        assert len(d) == len(evals)
        
        df = pd.DataFrame(d[20:], columns=["K", "Q", "R", "B", "N", "P", "k", "q", "r", "b", "n", "p"])
        df["Eval"] = evals[20:]
    
        df["Qq"] = df["Q"] - df["q"]
        df["Rr"] = df["R"] - df["r"]
        df["Bb"] = df["B"] - df["b"]
        df["Nn"] = df["N"] - df["n"]
        df["Pp"] = df["P"] - df["p"]

        df = df.drop(columns=["K", "Q", "R", "B", "N", "P", "k", "q", "r", "b", "n", "p"])
        
        big_df = pd.concat([big_df, df])
    
    big_df = big_df[~big_df["Eval"].str.startswith("#")]
    big_df = big_df.astype(float)
    return big_df

# %%
df = get_data()

# %%
X = sm.add_constant(df.drop(columns={"Eval"}))
Y = df["Eval"]

# %%
model = sm.OLS(Y, X)

# %%
results = model.fit()

# %%
print(results.summary())

# %%
def moves_to_df(moves):
    s = moves.replace("[", "").replace("]", "")
    s = s.split(" ")
    s = s[:-1]
    
    # Small fix for when last move is mate
    if len(s) % 8 != 0:
        s.insert(-3, "%eval")
        s.insert(-3, "#0")

    df = pd.DataFrame.from_dict({
        "Move": s[1::8],
        "Eval": s[4::8],
    }, orient="index").transpose()
    
    df["MoveNumber"] = (df.index // 2) + 1
    df["MoveSide"] = (df.index % 2)
    
    # Only first 200 moves have analysis
    df = df.head(200)

    return df

# %%
get_next_analysed_game()[-1]

# %%
def get_and_parse_next_analysed_game():
    while True:
        data = get_next_analysed_game()
        game = params_to_dict(data[:-1])
        
        is_good_game = all([
            game["TimeControl"].split("+")[0] in ["600", "900", "1200", "1800"],
            abs(float(game["WhiteRatingDiff"])) <= 20,
            abs(float(game["BlackRatingDiff"])) <= 20,
            abs(int(game["WhiteElo"]) - int(game["BlackElo"])) <= 200,
            game["Termination"] in ["Normal", "Time forfeit"]
        ])
        
        if not is_good_game:
            continue
        
        moves = moves_to_df(data[-1])
        
        # FirstMoves = moves["Move"].values[:20]
        # FirstMoves = " ".join(FirstMoves)
        # FirstMoves = FirstMoves.replace("?", "").replace("!", "").replace("+", "").replace("#", "")
        # game["FirstMoves"] = FirstMoves

        return game, moves

# %%
def get_two_dfs(size=10_000):
    games_list = []
    moves_list = []
    n_good_games_found = 0
    while n_good_games_found < size:
        
        try:
            a, b = get_and_parse_next_analysed_game()
        except:
            continue

        game_id = a["Site"].split("/")[-1]
        a["GameId"] = game_id
        b["GameId"] = game_id
        
        games_list.append(a)
        moves_list.append(b)
        
        n_good_games_found += 1
        
    return (
        pd.DataFrame(games_list),
        pd.concat(moves_list)
    )

# %% [markdown]
# **Start parsing**

# %%
PGN_FILE = "pgn/lichess_db_standard_rated_2018-06.pgn"
print(f"PGN file size (bytes): {getsize(PGN_FILE):,}")

f = open(PGN_FILE, mode="r")

# OFFSET = 0
# f.seek(OFFSET)
# while True:
#     line = f.readline()
#     if line.startswith("1."):
#         break

# %%
batch_size = 10_000
n_batches = 25

# %%
for batch in range(1, n_batches + 1):

    df_games, df_moves = get_two_dfs(batch_size)

    df_games = df_games[[
        "GameId",
        "Result",
        "TimeControl",
        "Termination",
        
        "White",
        "Black",
        "WhiteElo",
        "BlackElo",
        "WhiteRatingDiff",
        "BlackRatingDiff",
        "ECO",
        "Opening"
    ]]

    df_games["WhiteElo"] = df_games["WhiteElo"].astype(int)
    df_games["BlackElo"] = df_games["BlackElo"].astype(int)

    df_games["WhiteRatingDiff"] = df_games["WhiteRatingDiff"].astype(int)
    df_games["BlackRatingDiff"] = df_games["BlackRatingDiff"].astype(int)
    
    # Assert ids are the same in both dfs
    ids = set(df_games["GameId"]) & set(df_moves["GameId"])
    df_games = df_games[ df_games["GameId"].isin(ids) ]
    df_moves = df_moves[ df_moves["GameId"].isin(ids) ]
    assert set(df_games["GameId"]) == set(df_moves["GameId"])

    df_games.to_parquet(f"parsed/batch_{batch}_games.parquet")
    df_moves.to_parquet(f"parsed/batch_{batch}_moves.parquet")

    print(f"Saved batch #{batch}")

# %%
print(f"Last cursor position (bytes): {f.tell():,}")

# %%
# Last cursor position (bytes): 42,669,125,447
